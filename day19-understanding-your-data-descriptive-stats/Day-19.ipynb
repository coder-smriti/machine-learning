# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# # How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # How does the data look like?

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 862          863         1       1
# 588          589         0       3
# 398          399         0       2
# 833          834         0       3
# 512          513         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 588                              Gilinski, Mr. Eliezer    male  22.0      0
# 398                                   Pain, Dr. Alfred    male  23.0      0
# 833                             Augustsson, Mr. Albert    male  23.0      0
# 512                          McGough, Mr. James Robert    male  36.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 862      0     17466  25.9292   D17        S
# 588      0     14973   8.0500   NaN        S
# 398      0    244278  10.5000   NaN        S
# 833      0    347468   7.8542   NaN        S
# 512      0  PC 17473  26.2875   E25        S

# %% [markdown]
# # What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %% [markdown]
# # Are there any missing values?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # How is the correlation between cols?

# %%
df.corr()['Survived']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.corr()['Survived']
#
# File ~/jupyter-env/lib/python3.14/site-packages/pandas/core/frame.py:13135, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13131         """  # noqa: E501
#   13132         data = self._get_numeric_data() if numeric_only else self
#   13133         cols = data.columns
#   13134         idx = cols.copy()
# > 13135         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13136
#   13137         if method == "pearson":
#   13138             correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/jupyter-env/lib/python3.14/site-packages/pandas/core/frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2077                [2, 4.5, Timestamp('2000-01-02 00:00:00')]], dtype=object)
#    2078         """
#    2079         if dtype is not None:
#    2080             dtype = np.dtype(dtype)
# -> 2081         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2082         if result.dtype is not dtype:
#    2083             result = np.asarray(result, dtype=dtype)
#    2084
#
# File ~/jupyter-env/lib/python3.14/site-packages/pandas/core/internals/managers.py:1885, in BlockManager.as_array(self, dtype, copy, na_value)
#    1883         arr.flags.writeable = False
#    1884 else:
# -> 1885     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1886     # The underlying data was copied within _interleave, so no need
#    1887     # to further copy if copy=True or setting na_value
#    1889 if na_value is lib.no_default:
#
# File ~/jupyter-env/lib/python3.14/site-packages/pandas/core/internals/managers.py:1938, in BlockManager._interleave(self, dtype, na_value)
#    1932 rl = blk.mgr_locs
#    1933 if blk.is_extension:
#    1934     # Avoid implicit conversion of extension blocks to object
#    1935
#    1936     # error: Item "ndarray" of "Union[ndarray, ExtensionArray]" has no
#    1937     # attribute "to_numpy"
# -> 1938     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1939         dtype=dtype,
#    1940         na_value=na_value,
#    1941     )
#    1942 else:
#    1943     arr = blk.get_values(dtype)
#
# File ~/jupyter-env/lib/python3.14/site-packages/pandas/core/arrays/numpy_.py:589, in NumpyExtensionArray.to_numpy(self, dtype, copy, na_value)
#     586         result = result.view()
#     587         result.flags.writeable = False
# --> 589 result = np.asarray(result, dtype=dtype)
#     591 if copy and result is self._ndarray:
#     592     result = result.copy()
#
# ValueError: could not convert string to float: 'Braund, Mr. Owen Harris'
