# %%
import pandas as pd

# %%
import os

# %%
print (os.getcwd())
# Out:
# C:\Users\shrut\ml-learning

# %%
df = pd.read_csv('tested.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# !pip uninstall matplotlib -y
# Out:
# Found existing installation: matplotlib 3.10.0
# error: uninstall-no-record-file
#
# Cannot uninstall matplotlib 3.10.0
#
# The package's contents are unknown: no RECORD file was found for matplotlib.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps matplotlib==3.10.0

# %%
# !pip install --user ydata-profiling
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\shrut\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\shrut\anaconda3\Lib\site-packages)

# %%
# !conda install -c conda-forge ydata-profiling -y
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# CondaMemoryError: The conda process ran out of memory. Increase system memory and/or try again.

# %%
import ydata_profiling
print("Installed successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import ydata_profiling
#       2 print("Installed successfully")
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\shrut\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install ydata-profiling
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\shrut\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\shrut\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\shrut\anaconda3\Lib\site-packages)

# %%
import ydata_profiling
print("ydata_profiling installed")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import ydata_profiling
#       2 print("ydata_profiling installed")
#
# ModuleNotFoundError: No module named 'ydata_profiling'
