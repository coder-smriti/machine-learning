# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open('model/ohe_sex.pkl','rb'))
ohe_embarked = pickle.load(open('model/ohe_embarked.pkl','rb'))
clf = pickle.load(open('model/clf.pkl','rb'))

# %%
test_input = np.array([2,'male',331.0,0,0,10.5,'S'],dtype=object).reshape(1,7)

# %%
test_input

# %%
array([[2,'male',331.0,0,0,10.5,'S'],dtype=object)

# %%
test_input_sex = ohe_sex.transform(test_sex.transforme(test_input[:,1],reshape(1,1))

# %%
test_input_sex

# %%
test_input_embarked = ohe_embarked.transform(test_embarked.transforme(test_input[:,1],reshape(1,1))

# %%
test_input_embarked

# %%
rmed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis =1)

# %%
test_input_age = ohe_age.transform(test_age.transforme(test_input[:,1],reshape(1,1))

# %%
test_input_transformed.shape

# %%
clf.predict(test_input_transformed)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
