# %% [markdown]
# # normalization

# %%
import numpy as np 
import pandas as pd 
import matplotlib as plt 
import seaborn as sns

# %%
df= pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])
df.columns=['Class lable', 'Alcohol', 'Malic acid']

# %%
df
# Out:
#      Class lable  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
color_dict={1:'red',3:'green',2:'blue'}
sns.scatterplot(x = 'Alcohol', y = 'Malic acid',hue = 'Class lable',data = df, palette=color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
print("Column names in DataFrame:")
print(df.columns.tolist())
target_column = 'df.columns[-1]'
X_train, X_test, Y_train, Y_test = train_test_split(df.drop(target_column, axis=1),
                                                    df[target_column],
                                                    test_size=0.3,
                                                    random_state=0)
X_train.shape, X_test.shape
# Out:
# Column names in DataFrame:
# ['Class lable', 'Alcohol', 'Malic acid']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 4
#       2 print(df.columns.tolist())
#       3 target_column = 'df.columns[-1]'
# ----> 4 X_train, X_test, Y_train, Y_test = train_test_split(df.drop(target_column, axis=1),
#       5                                                     df[target_column],
#       6                                                     test_size=0.3,
#       7                                                     random_state=0)
#       8 X_train.shape, X_test.shape
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, y_test = train_test_split(df.drop('Class lable', axis=1),
                                                    df['Class label'],
                                                    test_size=0.3,
                                                      random_state=0)
X_train.shape, x_test.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 3
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 from sklearn.preprocessing import MinMaxScaler
# ----> 2 scaler.fit(X_train)
#       3 X_train_scaled = scaler.transform(X_train)
#       4 X_test_scaled = scaler.transform(X_test)
#
# NameError: name 'scaler' is not defined

# %%
X_train_scaled = pd.DataFframe(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFframe(X_test_scaled, columns=X_test.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 X_train_scaled = pd.DataFframe(X_train_scaled, columns=X_train.columns)
#       2 X_test_scaled = pd.DataFframe(X_test_scaled, columns=X_test.columns)
#
# AttributeError: module 'pandas' has no attribute 'DataFframe'

# %%
np.round(X_train.describe(), 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 np.round(X_train.describe(), 1)
#
# NameError: name 'X_train' is not defined

# %%
fig (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))
ax1.scatter(X_train['Alcohol'], X_train['Malic acid'],c=y_train)
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Alcohol'], X_train_scaled['Malic acid'],c=y_train)
plt.show()

# %%
fig (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))
ax1.set_title('Before Scalling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax1)
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax1)

ax2.set_title('After Standard Scalling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()

# %%
fig (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))
ax1.set_title('Before Scalling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax1)

ax2.set_title('Alcohol Distribution After Standard Scalling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
plt.show()

# %%
fig (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))
ax1.set_title('Before Scalling')
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax1)

ax2.set_title('Alcohol Distribution After Standard Scalling')
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()
