# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train (1).csv',usecols=['Age','Fare','Survived'])

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean()*100
# Out:
# Survived     0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
X = df.drop(columns =['Survived'])
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [raw]
# X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train
# Out:
#       Age      Fare
# 30   40.0   27.7208
# 10    4.0   16.7000
# 873  47.0    9.0000
# 182   9.0   31.3875
# 876  20.0    9.8458
# ..    ...       ...
# 534  30.0    8.6625
# 584   NaN    8.7125
# 493  71.0   49.5042
# 527   NaN  221.7792
# 168   NaN   25.9250
#
# [712 rows x 2 columns]

# %%
X_train.head()
# Out:
#       Age     Fare
# 30   40.0  27.7208
# 10    4.0  16.7000
# 873  47.0   9.0000
# 182   9.0  31.3875
# 876  20.0   9.8458

# %%
X_train['Age_imputed'] = X_train['Age']
X_test['Age_imputed'] = X_test['Age']

# %%
X_test.head()
# Out:
#       Age     Fare  Age_imputed
# 707  42.0  26.2875         42.0
# 37   21.0   8.0500         21.0
# 615  24.0  65.0000         24.0
# 169  28.0  56.4958         28.0
# 68   17.0   7.9250         17.0

# %%
X_train['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
X_test['Age_imputed'][X_test['Age_imputed'].isnull()] = X_test['Age'].dropna().sample(X_test['Age'].isnull().sum()).values
# Out:
# C:\Users\shrut\AppData\Local\Temp\ipykernel_11820\1252176479.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
X_train['Age'].dropna().sample(1).values
# Out:
# array([29.])

# %%
X_train
# Out:
#       Age      Fare  Age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125         25.0
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792         22.0
# 168   NaN   25.9250         33.0
#
# [712 rows x 3 columns]

# %%
X_train['Age'].isnull().sum()
# Out:
# np.int64(148)

# %%
X_train
# Out:
#       Age      Fare  Age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125         25.0
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792         22.0
# 168   NaN   25.9250         33.0
#
# [712 rows x 3 columns]

# %%
X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
# Out:
# array([23.  , 28.  , 50.  , 16.  , 31.  , 45.  , 16.  , 18.  , 19.  ,
#        22.  , 46.  , 48.  , 28.  , 52.  , 19.  , 24.  , 21.  , 39.  ,
#        22.  ,  4.  , 27.  , 22.  , 45.  , 49.  , 29.  , 27.  , 18.  ,
#        42.  , 37.  , 58.  , 31.  , 29.  , 26.  , 10.  , 47.  , 32.  ,
#        36.5 , 39.  , 36.  , 22.  , 39.  ,  0.42, 40.  , 19.  , 29.  ,
#        16.  , 27.  , 30.  , 58.  , 61.  , 36.  , 14.  , 40.  , 45.  ,
#        22.  , 45.  ,  9.  , 42.  , 21.  , 31.  , 36.  , 36.  , 33.  ,
#        21.  ,  1.  , 14.  , 31.  , 65.  , 27.  , 34.  , 47.  , 42.  ,
#        42.  , 24.  , 34.  , 34.  , 23.5 , 30.  , 49.  , 36.  , 26.  ,
#        20.  , 25.  , 29.  , 16.  , 38.  , 15.  ,  4.  ,  3.  , 16.  ,
#        17.  , 34.  , 39.  , 32.  , 29.  , 17.  , 24.  , 21.  , 25.  ,
#        39.  , 24.  , 27.  , 51.  , 54.  , 17.  , 34.  , 39.  , 20.  ,
#        30.  , 54.  , 22.  , 41.  , 28.  , 65.  , 43.  , 62.  , 18.  ,
# ...

# %%
sns.displot(X_train['Age'],label='Original',hist=True)
sns.displot(X_train['Age_imputed'],label='Imputed',hist=True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 sns.displot(X_train['Age'],label='Original',hist=True)
#       2 sns.displot(X_train['Age_imputed'],label='Imputed',hist=True)
#       3 plt.legend()
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:2193, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2190 if p.univariate:
#    2192     _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2193     p.plot_univariate_histogram(**hist_kws)
#    2195 else:
#    2197     _assign_default_kwargs(hist_kws, p.plot_bivariate_histogram, histplot)
#
# ...

# %%
print('Original variable varince: ', X_train['Age'].var())
print('Variance after random iputation: ', X_train['Age_imputed'].var())
# Out:
# Original variable varince:  204.3495133904614
# Variance after random iputation:  202.39571448486072

# %%
X_train[['Fare','Age','Age_imputed']].cov()
# Out:
#                     Fare         Age  Age_imputed
# Fare         2368.246832   71.512440    53.910483
# Age            71.512440  204.349513   204.349513
# Age_imputed    53.910483  204.349513   202.395714

# %%
X_train[['Age','Age_imputed']].boxplot()
# Out:
# <Axes: >

# %%
sampled_value = X_train['Age'].dropna().sample(1, random_state=int(observation['Fare']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 sampled_value = X_train['Age'].dropna().sample(1, random_state=int(observation['Fare']))
#
# NameError: name 'observation' is not defined

# %%
data = pd.read_csv('house-train.csv',usecols=['GargeQual','FireplaceQuau','SalePrice'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 data = pd.read_csv('house-train.csv',usecols=['GargeQual','FireplaceQuau','SalePrice'])
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.isnull().mean()
# Out:
# Survived    0.000000
# Age         0.198653
# Fare        0.000000
# dtype: float64

# %%
X = df.drop(columns =['Survived'])
y = df['Survived']
