# %%
import pandas as pd
import requests

# %%
response = request.get('')

# %%
df = pd.DataFrame(response.json()['result'](['id','title','overview','relase_date','popularity'])

# %%
df

# %%
df.shape
