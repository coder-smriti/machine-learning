# %%
import numpy as np
import pandas as pd 

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('tested.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.drop(columns=['PassengerId','Name','Ticket','Cabin'],inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  34.5      0      0   7.8292        Q
# 1         1       3  female  47.0      1      0   7.0000        S
# 2         0       2    male  62.0      0      0   9.6875        Q
# 3         0       3    male  27.0      0      0   8.6625        S
# 4         1       3  female  22.0      1      1  12.2875        S

# %%
# step-1 train/test/split
X_train,X_test,y_train,y_test =train_test_split(df.drop(columns=['Survived']),
                                                df['Survived'],
                                                test_size=0.2,
                                                random_state=42)

# %%
X_train.head(2)
# Out:
#      Pclass   Sex   Age  SibSp  Parch  Fare Embarked
# 336       2  male  32.0      0      0  13.0        S
# 31        2  male  24.0      2      0  31.5        S

# %%
y_train.head()
# Out:
# 336    0
# 31     0
# 84     0
# 287    0
# 317    0
# Name: Survived, dtype: int64

# %%
df.isnull().sum()
# Out:
# Survived     0
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Embarked     0
# dtype: int64

# %%
si_age = SimpleImputer()
si_embarked = SimpleImputer(strategy='most_frequent')
X_train_age = si_age.fit_transform(X_train[['Age']])
X_train_embarked = si_embarked.fit_transform(X_train[['Embarked']])
X_test_age = si_age.transform(X_test[['Age']])
X_test_embarked = si_embarked.transform(X_test[['Embarked']])

# %%
 X_train_embarked
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 334 stored elements and shape (334, 3)>

# %%
ohe_sex = OneHotEncoder(sparse_output = True , handle_unknown='ignore')
ohe_embarked = OneHotEncoder(sparse_output = True , handle_unknown='ignore')
X_train_sex = ohe_sex.fit_transform(X_train[['Sex']])
X_train_embarked = ohe_embarked.fit_transform(X_train_embarked)
X_test_sex = ohe_sex.transform(X_test[['Sex']])                                        
X_test_embarked = ohe_embarked.transform(X_test_embarked)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 4
#       2 ohe_embarked = OneHotEncoder(sparse_output = True , handle_unknown='ignore')
#       3 X_train_sex = ohe_sex.fit_transform(X_train[['Sex']])
# ----> 4 X_train_embarked = ohe_embarked.fit_transform(X_train_embarked)
#       5 X_test_sex = ohe_sex.transform(X_test[['Sex']])
#       6 X_test_embarked = ohe_embarked.transform(X_test_embarked)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:894, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     879         warnings.warn(
#     880             (
#     881                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    889             UserWarning,
#     890         )
#     892 if y is None:
#     893     # fit method of arity 1 (unsupervised transformation)
# --> 894     return self.fit(X, **fit_params).transform(X)
#     895 else:
#     896     # fit method of arity 2 (supervised transformation)
#     897     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:991, in OneHotEncoder.fit(self, X, y)
#     972 @_fit_context(prefer_skip_nested_validation=True)
#     973 def fit(self, X, y=None):
#     974     """
#     975     Fit OneHotEncoder to X.
#     976
#    (...)    989         Fitted encoder.
#     990     """
# --> 991     self._fit(
#     992         X,
#     993         handle_unknown=self.handle_unknown,
#     994         ensure_all_finite="allow-nan",
#     995     )
#     996     self._set_drop_idx()
#     997     self._n_features_outs = self._compute_n_features_outs()
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:83, in _BaseEncoder._fit(self, X, handle_unknown, ensure_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#      81 _check_n_features(self, X, reset=True)
#      82 _check_feature_names(self, X, reset=True)
# ---> 83 X_list, n_samples, n_features = self._check_X(
#      84     X, ensure_all_finite=ensure_all_finite
#      85 )
#      86 self.n_features_in_ = n_features
#      88 if self.categories != "auto":
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:49, in _BaseEncoder._check_X(self, X, ensure_all_finite)
#      36 """
#      37 Perform custom check_array:
#      38 - convert list of strings to object dtype
#    (...)     45
#      46 """
#      47 if not (hasattr(X, "iloc") and getattr(X, "ndim", 0) == 2):
#      48     # if not a dataframe, do normal check_array validation
# ---> 49     X_temp = check_array(X, dtype=None, ensure_all_finite=ensure_all_finite)
#      50     if not hasattr(X, "dtype") and np.issubdtype(X_temp.dtype, np.str_):
#      51         X = check_array(X, dtype=object, ensure_all_finite=ensure_all_finite)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1012, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1010 if sp.issparse(array):
#    1011     _ensure_no_complex_data(array)
# -> 1012     array = _ensure_sparse_format(
#    1013         array,
#    1014         accept_sparse=accept_sparse,
#    1015         dtype=dtype,
#    1016         copy=copy,
#    1017         ensure_all_finite=ensure_all_finite,
#    1018         accept_large_sparse=accept_large_sparse,
#    1019         estimator_name=estimator_name,
#    1020         input_name=input_name,
#    1021     )
#    1022     if ensure_2d and array.ndim < 2:
#    1023         raise ValueError(
#    1024             f"Expected 2D input, got input with shape {array.shape}.\n"
#    1025             "Reshape your data either using array.reshape(-1, 1) if "
#    1026             "your data has a single feature or array.reshape(1, -1) "
#    1027             "if it contains a single sample."
#    1028         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:611, in _ensure_sparse_format(sparse_container, accept_sparse, dtype, copy, ensure_all_finite, accept_large_sparse, estimator_name, input_name)
#     609 if accept_sparse is False:
#     610     padded_input = " for " + input_name if input_name else ""
# --> 611     raise TypeError(
#     612         f"Sparse data was passed{padded_input}, but dense data is required. "
#     613         "Use '.toarray()' to convert to a dense numpy array."
#     614     )
#     615 elif isinstance(accept_sparse, (list, tuple)):
#     616     if len(accept_sparse) == 0:
#
# TypeError: Sparse data was passed, but dense data is required. Use '.toarray()' to convert to a dense numpy array.

# %%
X_train.head(2)
# Out:
#      Pclass   Sex   Age  SibSp  Parch  Fare Embarked
# 336       2  male  32.0      0      0  13.0        S
# 31        2  male  24.0      2      0  31.5        S

# %%
X_train_embarked
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 334 stored elements and shape (334, 3)>

# %%
X_train_rem = X_train.drop(columns=['Sex','Age','Embarked'])

# %%
X_test_rem = X_test.drop(columns=['Sex','Age','Embarked'])

# %%
X_train_transformed = np.concatenate((X_train_rem,X_train_age,X_train_sex,X_train_embarked),axis=1)
X_test_transformed = np.concatenate((X_test_rem,X_test_age,X_test_sex,X_test_embarked),axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 X_train_transformed = np.concatenate((X_train_rem,X_train_age,X_train_sex,X_train_embarked),axis=1)
#       2 X_test_transformed = np.concatenate((X_test_rem,X_test_age,X_test_sex,X_test_embarked),axis=1)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 2 has 0 dimension(s)

# %%
X_train_transformed = np.concatenate(
    (X_train_rem, X_train_age, X_train_sex, X_train_embarked),
    axis=1
)

X_test_transformed = np.concatenate(
    (X_test_rem, X_test_age, X_test_sex, X_test_embarked),
    axis=1
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 X_train_transformed = np.concatenate(
#       2     (X_train_rem, X_train_age, X_train_sex, X_train_embarked),
#       3     axis=1
#       4 )
#       6 X_test_transformed = np.concatenate(
#       7     (X_test_rem, X_test_age, X_test_sex, X_test_embarked),
#       8     axis=1
#       9 )
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 2 has 0 dimension(s)

# %%
X_train_transformed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 X_train_transformed
#
# NameError: name 'X_train_transformed' is not defined

# %%
X_train_transformed.shape

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train_transformed,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 2
#       1 clf = DecisionTreeClassifier()
# ----> 2 clf.fit(X_train_transformed,y_train)
#
# NameError: name 'X_train_transformed' is not defined

# %%
y_pred = clf.predict(X_test_transformed)
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 y_pred = clf.predict(X_test_transformed)
#       2 y_pred
#
# NameError: name 'X_test_transformed' is not defined

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 2
#       1 from sklearn.metrics import accuracy_score
# ----> 2 accuracy_score(y_test,y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open('model/ohe_sex.pkl','rb'))
ohe_embarked = pickel.load(open('model/ohe_embarked.pkl','rb'))
clf = pickel.load(open('model/clf.pkl','rb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 ohe_sex = pickle.load(open('model/ohe_sex.pkl','rb'))
#       2 ohe_embarked = pickel.load(open('model/ohe_embarked.pkl','rb'))
#       3 clf = pickel.load(open('model/clf.pkl','rb'))
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model/ohe_sex.pkl'
